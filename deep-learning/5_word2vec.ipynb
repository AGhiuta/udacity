# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'of', 'originated', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.525133
# Nearest to used: crystal, hewitt, enumerated, terminates, flyby, batted, venereal, exhibited,
# Nearest to called: jean, forked, cossiga, euclid, mawr, decoy, whipple, hostage,
# Nearest to will: monomer, topologically, cantonal, grape, vx, allegiance, bookmakers, pournelle,
# Nearest to when: rmi, intervention, privatisation, relies, proteus, isthmus, touched, infrastructures,
# Nearest to up: solidifying, bront, mediated, adolescent, wherever, hockey, harry, patience,
# Nearest to also: gigabytes, codifying, longbowmen, dayan, descriptive, avoid, magnetic, badge,
# Nearest to who: vauxhall, tsuburaya, patrimony, visitors, cutaway, bootp, ligands, particles,
# Nearest to use: mcgowan, bitterly, jeet, lens, retire, spotless, floodplain, magnifying,
# Nearest to such: couplet, cosmology, trimester, monopolies, hashes, fertilize, infect, create,
# Nearest to his: prohibiting, foodborne, canteen, ymca, enamel, must, hoppers, cedar,
# Nearest to its: enrollment, conger, axiomatization, bitumen, tutsis, refining, heats, bedtime,
# Nearest to three: tanker, imperatives, benefactors, feminist, multiplication, norsemen, socialized, utilising,
# Nearest to would: dover, mews, eredivisie, fluffy, kerk, graphemes, railhead, implausible,
# Nearest to th: amazingly, dannebrog, esa, cuban, pueblo, monarchs, bahia, dyadic,
# Nearest to some: naturalization, curia, vox, humanoid, biosphere, subtitles, ratified, jer,
# Nearest to for: worldcom, resolute, criticized, kristen, underwood, autistic, further, bioleaching,
# Average loss at step 2000: 4.360921
# Average loss at step 4000: 3.868439
# Average loss at step 6000: 3.791782
# Average loss at step 8000: 3.686830
# Average loss at step 10000: 3.609457
# Nearest to used: racquets, prosperity, argue, lips, nicely, able, performed, hewitt,
# Nearest to called: cossiga, jean, decoy, clocks, forked, chants, walk, mawr,
# Nearest to will: bookmakers, can, transcendentalism, retroactive, topologically, would, represents, entered,
# Nearest to when: remaining, rmi, tradesmen, if, intervention, clin, instinctively, was,
# Nearest to up: difficult, wachowski, adolescent, solidifying, bront, discussing, bonfires, crewe,
# Nearest to also: which, unjustly, it, now, often, petrus, underscore, dixie,
# Nearest to who: he, and, grumpy, freddy, also, franke, membrane, gaucho,
# Nearest to use: mcgowan, lens, umlauts, categorically, soteriology, jeet, bitterly, sapphire,
# Nearest to such: well, cosmology, burdens, known, trumbull, ulam, jozef, fertilize,
# Nearest to his: their, her, the, s, its, prohibiting, anzus, defector,
# Nearest to its: the, his, bitumen, compatible, refining, their, heats, danorum,
# Nearest to three: six, eight, four, seven, five, two, nine, zero,
# Nearest to would: can, may, eredivisie, should, to, railhead, could, though,
# Nearest to th: knock, four, longships, albigensians, six, pueblo, calorimetry, amazingly,
# Nearest to some: many, travolta, humanoid, much, kul, shading, full, payloads,
# Nearest to for: incas, with, from, prattica, of, mineral, in, mired,
# Average loss at step 12000: 3.602927
# Average loss at step 14000: 3.573586
# Average loss at step 16000: 3.410747
# Average loss at step 18000: 3.457967
# Average loss at step 20000: 3.535912
# Nearest to used: able, racquets, performed, prosperity, argue, known, found, bitch,
# Nearest to called: decoy, clocks, forbade, remark, chants, cooley, collections, megali,
# Nearest to will: can, would, bookmakers, should, to, could, may, grosz,
# Nearest to when: if, remaining, plank, before, was, but, atonement, rmi,
# Nearest to up: difficult, pericles, discussing, facing, problems, crewe, spinster, adolescent,
# Nearest to also: which, now, often, still, not, who, usually, generally,
# Nearest to who: he, which, often, they, grumpy, there, also, franke,
# Nearest to use: umlauts, mcgowan, categorically, retire, assessments, magnifying, mechanical, soteriology,
# Nearest to such: well, known, burdens, cosmology, ulam, fertilize, trumbull, these,
# Nearest to his: their, her, its, the, alligators, preyed, this, midwives,
# Nearest to its: their, his, the, beatings, envoy, compatible, danorum, several,
# Nearest to three: four, six, eight, five, seven, two, zero, nine,
# Nearest to would: can, may, could, will, should, to, must, cannot,
# Nearest to th: albigensians, longships, knock, calorimetry, discussion, cuban, starboard, isbn,
# Nearest to some: many, most, these, the, several, other, their, various,
# Nearest to for: of, incas, with, from, after, original, as, by,
# Average loss at step 22000: 3.502299
# Average loss at step 24000: 3.491340
# Average loss at step 26000: 3.482501
# Average loss at step 28000: 3.477420
# Average loss at step 30000: 3.504931
# Nearest to used: known, able, found, liguria, regarded, available, performed, written,
# Nearest to called: decoy, clocks, und, forbade, remark, doi, alomar, stipulation,
# Nearest to will: would, can, may, should, could, must, bookmakers, to,
# Nearest to when: if, after, before, where, was, while, rmi, but,
# Nearest to up: pericles, down, him, discussing, crewe, facing, difficult, out,
# Nearest to also: often, now, usually, still, generally, petrus, which, always,
# Nearest to who: he, they, which, often, she, and, there, grumpy,
# Nearest to use: categorically, assessments, umlauts, mechanical, chinese, magnifying, pixels, simplifications,
# Nearest to such: well, known, these, burdens, ulam, elm, fertilize, including,
# Nearest to his: their, her, its, the, s, theodosius, your, prohibiting,
# Nearest to its: their, his, the, her, danorum, several, beatings, oriented,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to would: can, could, will, may, should, must, to, might,
# Nearest to th: isbn, eight, longships, albigensians, bulgakov, april, rd, calorimetry,
# Nearest to some: many, these, several, most, all, various, their, the,
# Nearest to for: after, with, ivo, incas, prattica, from, of, when,
# Average loss at step 32000: 3.499724
# Average loss at step 34000: 3.493066
# Average loss at step 36000: 3.453295
# Average loss at step 38000: 3.305833
# Average loss at step 40000: 3.426807
# Nearest to used: known, found, regarded, able, written, available, responsible, seen,
# Nearest to called: decoy, used, known, hessian, agrigentum, immolation, clocks, und,
# Nearest to will: can, would, could, may, should, must, might, cannot,
# Nearest to when: if, before, while, where, after, for, is, because,
# Nearest to up: out, them, down, him, off, pericles, difficult, discussing,
# Nearest to also: often, which, usually, still, now, sometimes, generally, petrus,
# Nearest to who: he, often, which, they, she, kanembu, grumpy, there,
# Nearest to use: categorically, assessments, pedersen, umlauts, subdivision, magnifying, rationing, mechanical,
# Nearest to such: well, known, including, these, ulam, burdens, like, trumbull,
# Nearest to his: her, their, its, your, the, s, my, prohibiting,
# Nearest to its: their, his, the, her, beatings, vance, oriented, flunitrazepam,
# Nearest to three: six, four, five, seven, two, eight, nine, one,
# Nearest to would: will, could, can, may, should, must, might, cannot,
# Nearest to th: bc, albigensians, rd, bulgakov, isbn, longships, contemporaneously, exhibited,
# Nearest to some: many, these, various, several, any, most, shading, those,
# Nearest to for: if, after, incas, when, prattica, in, sprites, from,
# Average loss at step 42000: 3.434445
# Average loss at step 44000: 3.451447
# Average loss at step 46000: 3.447073
# Average loss at step 48000: 3.355565
# Average loss at step 50000: 3.386941
# Nearest to used: known, written, available, regarded, able, found, seen, given,
# Nearest to called: known, named, used, decoy, frans, l, shari, und,
# Nearest to will: would, can, could, should, may, might, must, cannot,
# Nearest to when: if, while, before, after, where, since, although, during,
# Nearest to up: out, off, them, down, him, pericles, barrows, niue,
# Nearest to also: often, now, which, sometimes, still, usually, generally, originally,
# Nearest to who: he, which, she, there, they, often, generally, also,
# Nearest to use: categorically, assessments, hiroshima, magnifying, chinese, serve, authenticated, subdivision,
# Nearest to such: well, known, these, including, many, ulam, burdens, described,
# Nearest to his: their, her, its, my, your, alligators, the, tansley,
# Nearest to its: their, his, the, her, codified, algorithms, oriented, actresses,
# Nearest to three: seven, four, six, five, two, eight, nine, zero,
# Nearest to would: could, will, can, may, should, must, might, cannot,
# Nearest to th: six, bc, one, rd, exhibited, bulgakov, longships, albigensians,
# Nearest to some: many, several, these, various, both, most, any, the,
# Nearest to for: incas, after, on, by, including, bollywood, while, if,
# Average loss at step 52000: 3.432538
# Average loss at step 54000: 3.425175
# Average loss at step 56000: 3.437728
# Average loss at step 58000: 3.397843
# Average loss at step 60000: 3.391463
# Nearest to used: known, available, written, found, regarded, designed, called, able,
# Nearest to called: used, known, considered, named, shari, banjos, decoy, see,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to when: if, before, while, where, after, because, although, though,
# Nearest to up: out, off, down, them, him, back, pericles, niue,
# Nearest to also: now, still, often, sometimes, usually, only, generally, never,
# Nearest to who: he, she, which, they, still, now, fula, grumpy,
# Nearest to use: categorically, assessments, authenticated, umlauts, chilling, effectiveness, hiroshima, magnifying,
# Nearest to such: well, known, these, many, including, burdens, cosmonauts, follows,
# Nearest to his: her, their, its, my, your, anomalous, our, alligators,
# Nearest to its: their, his, the, her, algorithms, several, your, goats,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to would: could, will, can, may, should, might, must, cannot,
# Nearest to th: six, four, bc, rd, eight, five, one, isbn,
# Nearest to some: many, these, several, various, most, all, this, any,
# Nearest to for: of, including, if, after, incas, mired, without, when,
# Average loss at step 62000: 3.235561
# Average loss at step 64000: 3.252685
# Average loss at step 66000: 3.402082
# Average loss at step 68000: 3.393011
# Average loss at step 70000: 3.353601
# Nearest to used: known, available, regarded, written, responsible, found, applied, designed,
# Nearest to called: named, used, considered, known, pmod, immolation, bulldogs, decoy,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to when: if, before, while, where, because, after, though, however,
# Nearest to up: off, out, down, them, back, him, pericles, metternich,
# Nearest to also: still, now, often, which, sometimes, usually, never, generally,
# Nearest to who: he, she, kanembu, they, preemptive, which, hackman, grumpy,
# Nearest to use: assessments, categorically, most, authenticated, favoritism, effectiveness, zog, attract,
# Nearest to such: well, known, these, including, many, some, described, certain,
# Nearest to his: her, their, its, my, your, our, alligators, anomalous,
# Nearest to its: their, his, the, her, goats, several, brownlow, beatings,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Nearest to would: could, will, may, can, should, might, must, cannot,
# Nearest to th: bc, rd, eight, exhibited, six, ad, nd, third,
# Nearest to some: many, several, these, various, all, any, most, both,
# Nearest to for: incas, in, of, to, including, if, while, finds,
# Average loss at step 72000: 3.371392
# Average loss at step 74000: 3.351185
# Average loss at step 76000: 3.314606
# Average loss at step 78000: 3.349124
# Average loss at step 80000: 3.374741
# Nearest to used: known, available, written, found, designed, responsible, applied, seen,
# Nearest to called: considered, used, named, pmod, known, bulldogs, agrigentum, referred,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to when: before, if, after, though, during, although, while, where,
# Nearest to up: off, down, out, them, back, him, away, pericles,
# Nearest to also: still, now, often, sometimes, which, petrus, never, hanged,
# Nearest to who: he, she, they, still, never, now, grumpy, often,
# Nearest to use: categorically, because, assessments, effectiveness, magnifying, authenticated, favoritism, zog,
# Nearest to such: well, known, these, including, follows, certain, various, many,
# Nearest to his: her, their, its, my, your, our, the, multiprocessor,
# Nearest to its: their, his, her, the, your, codified, figurines, our,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to would: could, will, may, can, should, might, must, cannot,
# Nearest to th: bc, rd, five, second, third, nd, seven, contemporaneously,
# Nearest to some: many, several, various, these, most, any, numerous, all,
# Nearest to for: incas, including, after, if, mired, when, while, mach,
# Average loss at step 82000: 3.407259
# Average loss at step 84000: 3.408297
# Average loss at step 86000: 3.385275
# Average loss at step 88000: 3.351682
# Average loss at step 90000: 3.362887
# Nearest to used: known, seen, designed, available, applied, called, found, responsible,
# Nearest to called: named, used, considered, pmod, known, cooley, agrigentum, bulldogs,
# Nearest to will: would, could, can, may, might, should, must, cannot,
# Nearest to when: if, before, while, after, though, where, although, because,
# Nearest to up: off, out, down, them, back, him, away, together,
# Nearest to also: now, often, still, sometimes, which, petrus, never, actually,
# Nearest to who: he, she, they, often, still, fula, never, which,
# Nearest to use: categorically, chilling, assessments, because, interest, market, repositories, zog,
# Nearest to such: known, well, these, follows, certain, many, described, polo,
# Nearest to his: her, their, its, my, your, the, our, whose,
# Nearest to its: their, his, her, the, whose, your, codified, faculty,
# Nearest to three: five, four, two, seven, eight, six, nine, zero,
# Nearest to would: could, will, might, may, can, should, must, did,
# Nearest to th: bc, seven, rd, second, two, nine, contemporaneously, eight,
# Nearest to some: many, several, these, any, those, various, most, all,
# Nearest to for: including, after, incas, while, of, during, when, mired,
# Average loss at step 92000: 3.398272
# Average loss at step 94000: 3.253931
# Average loss at step 96000: 3.349587
# Average loss at step 98000: 3.244010
# Average loss at step 100000: 3.357697
# Nearest to used: available, designed, known, applied, found, responsible, able, considered,
# Nearest to called: named, used, considered, known, referred, frameworks, immolation, bulldogs,
# Nearest to will: would, could, can, may, might, must, should, cannot,
# Nearest to when: if, before, while, after, though, although, where, because,
# Nearest to up: off, out, down, them, back, him, together, away,
# Nearest to also: now, still, actually, never, sometimes, often, petrus, generally,
# Nearest to who: he, still, never, she, often, fula, that, actually,
# Nearest to use: categorically, chilling, repositories, assessments, authenticated, because, mindful, interest,
# Nearest to such: known, well, many, these, follows, certain, including, cosmonauts,
# Nearest to his: her, their, my, your, its, the, our, alligators,
# Nearest to its: their, his, the, her, your, codified, whose, goats,
# Nearest to three: five, four, two, seven, six, eight, nine, zero,
# Nearest to would: could, will, might, may, can, should, must, cannot,
# Nearest to th: bc, rd, second, nd, one, tubulin, third, four,
# Nearest to some: many, several, these, any, certain, various, numerous, those,
# Nearest to for: incas, when, after, if, without, before, legume, including,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
from itertools import compress

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  '''
  Batch generator for CBOW (Continuous Bag of Words).
  batch should be a shape of (batch_size, num_skips)
  Parameters
  ----------
  batch_size: number of words in each mini-batch
  num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
  skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
  '''

  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
    
  batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]

  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  for i in range(batch_size):
    mask = [1] * span
    mask[skip_window] = 0 # mask the center of the buffer
    batch[i, :] = list(compress(buffer, mask)) # the history and future words
    labels[i, 0] = buffer[skip_window] # the center of the buffer is the word to be predicted
    
    buffer.append(data[data_index]) # add a new word to the buffer
    data_index = (data_index + 1) % len(data) # move to the next word
    
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

batch, labels = generate_batch_cbow(batch_size=8, num_skips=8, skip_window=4)
print('    batch:', [[reverse_dictionary[bi] for bi in bbi] for bbi in batch])
print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: [['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used'], ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against'], ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early'], ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working'], ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class'], ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals'], ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including'], ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']]
#     labels: ['term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 4 # How many words to consider left and right.
num_skips = 8 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.zeros([batch_size, embedding_size])

  for i in range(num_skips):
        embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, i])

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.446951
# Nearest to world: hydrofoils, dinosaurs, iphigenia, precocious, tar, koo, tyrol, hadrian,
# Nearest to which: betrays, entertained, northwest, charon, benton, referred, database, lenoir,
# Nearest to they: movements, nage, cirencester, meiosis, diode, cervical, lojban, counteracting,
# Nearest to is: defaults, litigation, ambiguity, gunshot, cui, saville, activating, fledged,
# Nearest to four: cartoonish, serge, maoist, toru, unpaved, extrapolated, saimei, yerushalayim,
# Nearest to i: gesta, supported, velarized, chuppah, snapped, homeopathy, sorel, infects,
# Nearest to time: bute, snap, keywords, vinod, bois, fsm, napster, vanadium,
# Nearest to d: mbe, essenes, sultan, god, defended, interruption, bidirectional, buttstock,
# Nearest to th: lend, moderately, authorisation, cur, referring, instantiation, enlarging, timur,
# Nearest to history: dye, remit, glitch, soup, concertos, blackhawks, chronica, tropical,
# Nearest to some: abyss, riflemen, bistable, akhenaten, turnover, waterline, deg, ni,
# Nearest to this: pipelining, gods, perhaps, eponym, playwrights, franchisor, trauma, papacy,
# Nearest to state: does, zedong, namco, ustinov, roast, progress, grudge, bachchan,
# Nearest to eight: entailed, rid, theorizing, menial, glaucus, diphtheria, narnia, sussman,
# Nearest to one: causal, ore, outlook, undead, drying, presides, madeleine, isolating,
# Nearest to so: meant, hypotheses, fubar, filtered, ba, dore, officer, enhancers,
# Average loss at step 2000: 43.513371
# Average loss at step 4000: 22.613506
# Average loss at step 6000: 14.348245
# Average loss at step 8000: 10.475074
# Average loss at step 10000: 7.760807
# Nearest to world: gauze, retreat, byrnes, inns, civil, brockhaus, creators, hanging,
# Nearest to which: halfwidth, slovenian, laguna, kay, whitish, payment, mashing, cygni,
# Nearest to they: comp, entail, schwarzenegger, surveillance, together, protector, originated, yell,
# Nearest to is: was, are, were, had, has, grieg, adheres, osmosis,
# Nearest to four: three, two, frequently, family, mid, like, itself, monasteries,
# Nearest to i: respiratory, wiens, cabins, dependable, farmhouse, amt, encompassed, accident,
# Nearest to time: ferruccio, trip, characters, moveable, creoles, outkast, ttir, dump,
# Nearest to d: redman, merseburg, spectacled, karate, undeclared, plotting, gts, waldemar,
# Nearest to th: rd, punchline, nd, favorite, carolinas, hosting, two, commended,
# Nearest to history: poetess, goldfinger, death, motorized, strangeness, augustine, punic, family,
# Nearest to some: those, aye, many, groundwork, canister, foix, eds, sanity,
# Nearest to this: an, it, honorius, enlarging, allegory, sightseeing, that, aloha,
# Nearest to state: abet, university, press, saber, domingo, milwaukee, lear, normand,
# Nearest to eight: ballpark, tupi, fructose, authored, verisign, mips, processor, til,
# Nearest to one: kashima, astrophysicist, entrepreneurs, agave, siegel, var, oakley, nullified,
# Nearest to so: petitions, osiris, scrabble, remarriage, polymath, tipperary, afterwards, heliogabalus,
# Average loss at step 12000: 7.605907
# Average loss at step 14000: 7.478596
# Average loss at step 16000: 8.217315
# Average loss at step 18000: 8.225853
# Average loss at step 20000: 6.994701
# Nearest to world: creators, webzine, gemstone, hinted, cartoon, scarlet, demille, national,
# Nearest to which: that, this, azeri, aging, whose, sprite, tuskegee, kay,
# Nearest to they: it, sponsors, keeping, tetrahedral, leonidas, midrashic, sloti, these,
# Nearest to is: was, are, were, became, craze, intrusions, zigzag, has,
# Nearest to four: archetype, six, hexagonal, reemergence, insomnia, poorer, elmer, obstruction,
# Nearest to i: we, sobriety, g, dispositions, persecuted, tuck, independently, acth,
# Nearest to time: led, half, black, sold, political, weight, death, desired,
# Nearest to d: folks, moabite, nantucket, rupees, subjectivism, wifi, heimdall, bitten,
# Nearest to th: rd, nd, twentieth, stile, late, lincos, bce, lambda,
# Nearest to history: gif, collection, britain, revelation, watt, landing, presided, obeyed,
# Nearest to some: these, many, ambulance, grammer, cisco, any, midian, that,
# Nearest to this: which, a, outcast, belatedly, it, dissipate, soups, astonishment,
# Nearest to state: unhealthy, leinster, booker, bookkeeping, aeronautics, lent, lough, hua,
# Nearest to eight: educate, apollodorus, disclaimer, nine, eudoxus, ballad, fucking, gnostic,
# Nearest to one: counterfeiting, fortuitous, oldham, frs, aymara, pathetic, sindhu, roque,
# Nearest to so: subdivided, borgir, ffffff, confusing, bring, purchasers, lifelong, transceiver,
# Average loss at step 22000: 5.809250
# Average loss at step 24000: 5.887545
# Average loss at step 26000: 5.719564
# Average loss at step 28000: 6.173312
# Average loss at step 30000: 5.983600
# Nearest to world: colonists, sub, gaba, creators, shattuck, ostara, freeport, country,
# Nearest to which: this, adjoined, budding, it, located, still, that, malaysian,
# Nearest to they: you, hampton, humans, riflemen, dignitaries, virtues, originated, these,
# Nearest to is: was, are, were, makes, remains, became, exists, austrians,
# Nearest to four: three, nigger, daryl, nine, womanizer, larger, bioleaching, eight,
# Nearest to i: we, comm, unsure, bayard, dwarfed, hast, condense, impoverished,
# Nearest to time: end, least, toolkit, period, circumstance, crabbe, anions, range,
# Nearest to d: thiele, nantucket, deliveries, norse, glasnevin, animate, reproducible, krupp,
# Nearest to th: twentieth, nd, nineteenth, rd, turn, commended, maximise, next,
# Nearest to history: article, relations, boitano, multipurpose, dummies, reign, zhou, gluon,
# Nearest to some: many, other, gaussian, stabilize, diameters, rawlings, colbert, neoclassical,
# Nearest to this: what, it, whose, remembered, which, the, rolfe, that,
# Nearest to state: roaring, california, struggle, person, feature, raskin, area, associative,
# Nearest to eight: nine, seward, santa, sweden, emile, robbie, four, ecuadorian,
# Nearest to one: two, kittens, adherents, percent, cleave, suspecting, boas, tablature,
# Nearest to so: por, destructive, compromised, what, autoroute, beings, truss, negroes,
# Average loss at step 32000: 5.441551
# Average loss at step 34000: 5.486596
# Average loss at step 36000: 5.392502
# Average loss at step 38000: 5.711456
# Average loss at step 40000: 5.700473
# Nearest to world: webzine, ostara, crumb, frames, andrade, creators, tuba, scuttled,
# Nearest to which: usually, that, whose, it, tahoe, mentioning, asteraceae, eleusis,
# Nearest to they: avars, hampton, handed, hierarchies, mr, claymore, experiment, soldiers,
# Nearest to is: was, makes, are, exists, became, holds, gave, contains,
# Nearest to four: two, zero, six, three, proof, df, since, burns,
# Nearest to i: handed, avars, entrances, priori, hierarchies, shropshire, casino, sword,
# Nearest to time: potos, least, zelazny, englewood, toolkit, camelcase, auction, dissected,
# Nearest to d: m, topped, rafael, logic, crashed, r, semi, lad,
# Nearest to th: rd, twentieth, nd, turn, wozniak, notoc, tenth, nineteenth,
# Nearest to history: jews, christians, anti, domain, mix, christian, galicia, semitism,
# Nearest to some: many, several, drip, boles, solicited, peta, descendants, endorse,
# Nearest to this: its, the, it, any, that, manifests, which, thespis,
# Nearest to state: unfavorable, carbonates, rumsfeld, actuality, navy, reconquista, regulators, beatrice,
# Nearest to eight: nine, supermarket, linemen, waring, five, sprout, euphonium, trolleybus,
# Nearest to one: six, three, flanders, two, landed, arrows, macroscopic, zero,
# Nearest to so: por, define, belligerent, aniston, bristles, variously, qaddafi, mischievous,
# Average loss at step 42000: 5.402649
# Average loss at step 44000: 5.245649
# Average loss at step 46000: 5.190968
# Average loss at step 48000: 5.949778
# Average loss at step 50000: 6.142782
# Nearest to world: parties, politics, concept, austria, win, bet, politicians, waldensians,
# Nearest to which: that, what, this, when, goitre, pomona, forearm, prevenient,
# Nearest to they: lomond, we, justifying, compassion, virtues, driven, weakening, students,
# Nearest to is: was, were, are, makes, has, includes, exists, became,
# Nearest to four: aliyah, martians, momentarily, moabites, desert, rea, hotter, referenced,
# Nearest to i: g, bayard, flintstones, we, halved, shorts, been, that,
# Nearest to time: least, settles, point, roxy, trained, ballroom, guadalcanal, period,
# Nearest to d: empire, urals, automaton, levite, choosing, actors, choices, chemist,
# Nearest to th: nd, twentieth, rd, nineteenth, tenth, seventeenth, dumbarton, wozniak,
# Nearest to history: realm, list, sama, dummies, ernst, performances, production, literature,
# Nearest to some: various, several, many, descendants, these, others, dental, pillar,
# Nearest to this: it, the, what, troopers, which, its, whose, that,
# Nearest to state: claymore, palace, cardiology, normal, pet, door, soft, drinks,
# Nearest to eight: boosts, wangenheim, tubular, jass, rau, pa, referees, staples,
# Nearest to one: petrified, laminar, langford, impoverishment, lends, explorers, knockout, bc,
# Nearest to so: require, offer, how, paco, compromised, odegard, socialism, implant,
# Average loss at step 52000: 5.381284
# Average loss at step 54000: 4.765300
# Average loss at step 56000: 4.995667
# Average loss at step 58000: 4.798286
# Average loss at step 60000: 5.231788
# Nearest to world: bottom, flunitrazepam, gospel, bolivian, padawan, webzine, deprived, gaba,
# Nearest to which: that, this, it, alice, competitive, lex, spin, whether,
# Nearest to they: pipelined, she, caapi, tuireadh, i, lloyd, hula, vagantes,
# Nearest to is: was, are, represents, becomes, makes, exists, became, has,
# Nearest to four: trades, approximately, lomborg, dairy, hierarchies, avars, my, tv,
# Nearest to i: soluble, caveats, they, we, yelled, romanticized, manifest, sobriety,
# Nearest to time: year, settles, least, point, period, length, look, transition,
# Nearest to d: choosing, reconquest, tamara, acquiescence, marino, reside, blonde, araki,
# Nearest to th: twentieth, nd, nineteenth, rd, sixteenth, eighteenth, seventeenth, ad,
# Nearest to history: reappearance, kind, philosophy, baronies, faisal, development, understanding, dictionaries,
# Nearest to some: many, several, certain, most, these, numerous, other, all,
# Nearest to this: it, which, what, his, that, the, fermi, a,
# Nearest to state: exhibition, measures, z, spin, events, obtains, horse, equestrian,
# Nearest to eight: six, nine, seven, paine, graphically, wacky, cal, dolls,
# Nearest to one: schuschnigg, woe, speer, toot, nur, aurelian, withstand, ton,
# Nearest to so: events, exhibition, measures, spin, z, competitive, churches, horse,
# Average loss at step 62000: 5.011621
# Average loss at step 64000: 5.013718
# Average loss at step 66000: 5.145598
# Average loss at step 68000: 4.887633
# Average loss at step 70000: 4.980941
# Nearest to world: region, u, fretboard, screename, cordon, seafaring, ejaculate, gaba,
# Nearest to which: this, that, what, whose, it, these, currently, dunne,
# Nearest to they: we, evaporates, he, mancala, you, basques, subtracted, yourself,
# Nearest to is: was, are, became, makes, represents, were, includes, becomes,
# Nearest to four: seven, you, codata, malignancies, sio, five, guises, serious,
# Nearest to i: sylvester, muhammed, dislikes, ii, ultra, realise, hirohito, mens,
# Nearest to time: least, potos, zaghawa, point, beginning, end, reasons, observable,
# Nearest to d: krafft, relocating, socialized, delegations, opposites, axiomatization, subtitled, sympathizer,
# Nearest to th: twentieth, nineteenth, fourth, sixteenth, seventeenth, next, wozniak, hallstatt,
# Nearest to history: renminbi, discussion, dockyard, guess, disarmed, legitimacy, list, geography,
# Nearest to some: many, several, certain, these, all, various, their, hangovers,
# Nearest to this: it, which, another, that, an, a, dataset, the,
# Nearest to state: perkin, district, throwers, dictatorship, stemmed, starch, etching, dressing,
# Nearest to eight: six, nine, loudspeaker, two, three, consequential, weicker, roe,
# Nearest to one: breaded, deletions, mmc, stripping, brandeis, prophesies, adherents, gis,
# Nearest to so: allele, curd, ley, guybrush, circumcise, plan, nahuatl, mitigation,
# Average loss at step 72000: 5.151511
# Average loss at step 74000: 5.614655
# Average loss at step 76000: 4.983584
# Average loss at step 78000: 4.753321
# Average loss at step 80000: 4.498550
# Nearest to world: country, top, padawan, gaba, europe, industrial, change, fretboard,
# Nearest to which: electrical, saarland, watershed, migs, hampton, pet, hellenic, norwegian,
# Nearest to they: we, mancala, unbeatable, missions, caapi, not, censorware, kata,
# Nearest to is: are, was, became, exists, were, represents, makes, holds,
# Nearest to four: greenland, hd, fdp, since, ultima, exhibition, nine, eliot,
# Nearest to i: search, kindred, uncredited, competitive, sharp, ii, measures, greenland,
# Nearest to time: least, look, beginning, end, expense, potos, mid, ita,
# Nearest to d: oxygenated, drew, upstairs, relocating, deconvolution, telephus, lawns, enclave,
# Nearest to th: twentieth, nineteenth, sixteenth, seventeenth, fourth, eighteenth, tenth, third,
# Nearest to history: list, type, alchemy, geography, exploration, dictionary, adaptations, development,
# Nearest to some: many, various, certain, these, list, several, number, thousands,
# Nearest to this: it, a, the, another, that, an, what, fateful,
# Nearest to state: gen, vote, envy, fully, pet, circuits, drinks, norwegian,
# Nearest to eight: six, seven, britannica, four, nine, linemen, maule, newly,
# Nearest to one: change, obtains, fdp, greenland, morris, since, decline, train,
# Nearest to so: clinker, too, melcher, stated, duddy, haber, acetaldehyde, dieting,
# Average loss at step 82000: 4.654869
# Average loss at step 84000: 4.452755
# Average loss at step 86000: 4.334790
# Average loss at step 88000: 4.160588
# Average loss at step 90000: 4.343868
# Nearest to world: country, creators, miltiades, waned, europe, gaba, vietnam, rebuilding,
# Nearest to which: that, this, dido, often, it, what, still, nike,
# Nearest to they: we, reliable, hula, them, their, those, kata, tactically,
# Nearest to is: was, exists, are, makes, were, remains, became, includes,
# Nearest to four: three, six, seven, straightforwardly, five, two, cti, berlitz,
# Nearest to i: we, g, settles, mancala, fide, trapped, dismemberment, rangoon,
# Nearest to time: least, end, look, beginning, closure, meeting, cougars, debbie,
# Nearest to d: strikeout, cordial, l, nilotic, bart, confounded, carousel, c,
# Nearest to th: nineteenth, twentieth, sixteenth, next, fifteenth, third, st, uniforms,
# Nearest to history: translation, criticism, palace, veterans, exploration, mob, hinged, hungarian,
# Nearest to some: many, certain, numerous, different, most, several, these, exhorted,
# Nearest to this: it, a, the, still, another, an, any, which,
# Nearest to state: area, dictatorship, seat, pinstripes, distantly, vedas, attend, topography,
# Nearest to eight: six, strapped, bara, emancipated, accidentally, deeply, iso, vickers,
# Nearest to one: limitations, nyc, isa, corel, millay, ten, straightforwardly, menus,
# Nearest to so: anything, nothing, chani, usaf, warts, druids, dependant, backfired,
# Average loss at step 92000: 4.354781
# Average loss at step 94000: 3.913664
# Average loss at step 96000: 3.861245
# Average loss at step 98000: 4.198579
# Average loss at step 100000: 4.114027
# Nearest to world: galaxy, miltiades, outdoor, creators, universe, hopeless, strain, gaba,
# Nearest to which: that, this, who, what, where, these, whose, dagon,
# Nearest to they: he, we, i, you, comptroller, inflectional, lomond, those,
# Nearest to is: was, are, makes, exists, became, remains, represents, produces,
# Nearest to four: three, two, five, eight, bothnian, beaulieu, mauss, hyrcanus,
# Nearest to i: we, they, ii, scriptwriter, zheng, langer, embroidered, mens,
# Nearest to time: look, least, age, end, year, decade, rate, beginning,
# Nearest to d: b, maguire, counteracting, inappropriately, redman, hariri, zeroes, dore,
# Nearest to th: rd, nagasaki, ago, vichy, atoms, sliding, brett, workmen,
# Nearest to history: geography, version, view, culture, description, usage, kurosawa, course,
# Nearest to some: many, several, these, various, multiple, all, most, numerous,
# Nearest to this: an, it, which, whose, a, the, that, amiable,
# Nearest to state: republic, legislature, committee, electoral, reconnection, fbi, nation, merging,
# Nearest to eight: nine, four, bitola, seven, antisense, uploaded, reenactment, disastrously,
# Nearest to one: tanker, alaska, evoked, umno, fronting, imagine, maxine, spink,
# Nearest to so: loud, diffuse, greenland, ceased, completely, skilled, ports, exhibition,
